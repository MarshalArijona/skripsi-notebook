# %%
import torch
import pickle
import time
import numpy as np
from torch.autograd import Variable
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib
import matplotlib.pyplot as plt
from matplotlib import gridspec
import matplotlib.patches as mpatches

# %%
is_cuda = torch.cuda.is_available()

# %%
seed = 10

n_classes = 10
#dimension of z or latent representation
z_dimension = 10
#dimension of X or data
X_dimension = 784
#dimension of label of data
y_dimension = 10

TRAIN_BATCH_SIZE = 100
VALID_BATCH_SIZE = 1000
EPOCHS = 1000
N = 1000
TINY_ERROR = 1e-15
DATA_PATH = "/floyd/input/skripsi_datasets_2/"
cuda = torch.device('cuda')

training_reconstruction_loss = []
training_generator_loss = []
training_discriminator_loss = []
training_generator_sample = []

# %%
class Encoder_net(nn.Module):
    def __init__(self):
        super(Encoder_net, self).__init__()
        self.layer1 = nn.Linear(X_dimension, N)
        self.layer2 = nn.Linear(N, N)
        self.layer3 = nn.Linear(N, z_dimension)
    
    def forward(self, x):
        x = F.dropout(self.layer1(x), p=0.5, training=self.training)
        x = F.relu(x)
        x = F.dropout(self.layer2(x), p=0.5, training=self.training)
        x = F.relu(x)
        x_gauss = self.layer3(x)
        
        return x_gauss

class Decoder_net(nn.Module):
    def __init__(self):
        super(Decoder_net, self).__init__()
        self.layer1 = nn.Linear(z_dimension, N)
        self.layer2 = nn.Linear(N,N)
        self.layer3 = nn.Linear(N,X_dimension)
        
    def forward(self, x):
        x = F.dropout(self.layer1(x), p=0.5, training=self.training)
        x = F.relu(x)
        x = F.dropout(self.layer2(x), p=0.5, training=self.training)
        x = self.layer3(x)
        
        return F.sigmoid(x)

class Discriminator_net_gauss(nn.Module):
    def __init__(self):
        super(Discriminator_net_gauss, self).__init__()
        self.layer1 = nn.Linear(z_dimension, N)
        self.layer2 = nn.Linear(N, N)
        self.layer3 = nn.Linear(N, 1)
    
    def forward(self, x):
        x = F.dropout(self.layer1(x), p=0.5, training=self.training)
        x = F.relu(x)
        x = F.dropout(self.layer2(x), p=0.5, training=self.training)
        x = F.relu(x)
        
        return F.sigmoid(self.layer3(x))

# %%
trainset_labeled = pickle.load(open(DATA_PATH + "train_labeled.p", "rb"))
trainset_unlabeled = pickle.load(open(DATA_PATH + "train_unlabeled.p", "rb"))
# Set -1 as labels for unlabeled data
trainset_unlabeled._train_labels = torch.from_numpy(np.array([-1] * 47000))
validset = pickle.load(open(DATA_PATH + "validation.p", "rb"))
train_labeled_loader = torch.utils.data.DataLoader(trainset_labeled,
                                                       batch_size=TRAIN_BATCH_SIZE,
                                                       shuffle=True)

train_unlabeled_loader = torch.utils.data.DataLoader(trainset_unlabeled,
                                                         batch_size=TRAIN_BATCH_SIZE,
                                                         shuffle=True)

valid_loader = torch.utils.data.DataLoader(validset, batch_size=VALID_BATCH_SIZE, shuffle=True)
# Out:
# 3000
# 750

# %%
def train_one_epoch(decoder, encoder, discriminator_gauss, decoder_optimizer, encoder_optimizer, generator_optimizer, discriminator_optimizer, data_loader):
    encoder = encoder.train()
    decoder = decoder.train()
    discriminator_gauss.train()
    
    discriminator_loss = None
    generator_loss = None
    reconstruction_loss = None
    
    for X, target in data_loader:
        X = X * 0.3081 + 0.1307
        X = X.resize(TRAIN_BATCH_SIZE, X_dimension)
        X, target = Variable(X), Variable(target)
        
        if is_cuda:
            X, target = X.cuda(cuda), target.cuda(cuda)
            
        decoder.zero_grad()
        encoder.zero_grad()
        discriminator_gauss.zero_grad()
        
        #reconstruction phase
        z_sample = encoder(X)
        X_sample = decoder(z_sample)
        compared_with_original = X.resize(TRAIN_BATCH_SIZE, X_dimension)
        mse_loss = torch.nn.MSELoss()
        reconstruction_loss = mse_loss(X_sample + TINY_ERROR, compared_with_original + TINY_ERROR)
        
        reconstruction_loss.backward()
        decoder_optimizer.step()
        encoder_optimizer.step()
        
        decoder.zero_grad()
        encoder.zero_grad()
        discriminator_gauss.zero_grad()
        
        #regularization phase
        #Train Discriminator
        encoder = encoder.eval()
        z_real_gauss = Variable(torch.empty(TRAIN_BATCH_SIZE, z_dimension).normal_(mean=0, std=1.0))
        
        if is_cuda:
            z_real_gauss = z_real_gauss.cuda(cuda)
        
        z_fake_gauss = encoder(X)
        
        discriminator_real_gauss = discriminator_gauss(z_real_gauss)
        discriminator_fake_gauss = discriminator_gauss(z_fake_gauss)
        
        discriminator_loss = -torch.mean(torch.log(discriminator_real_gauss + TINY_ERROR) + torch.log(1 - discriminator_fake_gauss + TINY_ERROR))
        
        discriminator_loss.backward()
        discriminator_optimizer.step()
        
        decoder.zero_grad()
        encoder.zero_grad()
        discriminator_gauss.zero_grad()
        
        #Train Generator
        encoder = encoder.train()
        z_fake_gauss = encoder(X)
        
        generator_fake_gauss = discriminator_gauss(z_fake_gauss)
        generator_loss = -torch.mean(torch.log(generator_fake_gauss + TINY_ERROR))
        
        generator_loss.backward()
        generator_optimizer.step()
        
    return discriminator_loss, generator_loss, reconstruction_loss

# %%
def train_model(train_labeled_loader, train_unlabeled_loader, valid_loader):
    torch.manual_seed(10)

    if is_cuda:
        encoder = Encoder_net().cuda(cuda)
        decoder = Decoder_net().cuda(cuda)
        discriminator_gauss = Discriminator_net_gauss().cuda(cuda)
    else:
        encoder = Encoder_net()
        decoder = Decoder_net()
        discriminator_gauss = Discriminator_net_gauss()

    #learning rates for optimization
    learning_rate_1 = 0.0001
    learning_rate_2 = 0.00005

    #optimization for decoder and encoder
    decoder_optimizer = optim.Adam(decoder.parameters(), lr=learning_rate_1)
    encoder_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate_1)

    generator_optimizer = optim.Adam(encoder.parameters(), lr=learning_rate_2)
    discriminator_optimizer = optim.Adam(discriminator_gauss.parameters(), lr=learning_rate_2)

    for epoch in range(EPOCHS):
        start_time = time.time()
        discriminator_loss, generator_loss, reconstruction_loss = train_one_epoch(decoder, encoder, discriminator_gauss, 
                                                                              decoder_optimizer, encoder_optimizer, generator_optimizer, 
                                                                              discriminator_optimizer, train_unlabeled_loader)
        
        epoch_time = time.time() - start_time
        if epoch % 10 == 0:
            training_reconstruction_loss.append(reconstruction_loss)
            training_generator_loss.append(generator_loss)
            training_discriminator_loss.append(discriminator_loss)
            print('Epoch-{}, Time-{:.2}, Discriminator_loss-{:.4}, Generator_loss-{:.4}, reconstruction_loss-{:.4}'.format(epoch, epoch_time, discriminator_loss.item(), generator_loss.item(), reconstruction_loss.item()))
    
        if epoch % 20 == 0:
            encoder = encoder.eval()
            decoder = decoder.eval()
            discriminator_gauss = discriminator_gauss.eval()
            
            X_test = None
            y_test = None

            for X, target in valid_loader:
                X_test = X
                y_test = target
                break

            if is_cuda:
                X_test = X_test.cuda(cuda)
                
            X_test = X_test.resize(VALID_BATCH_SIZE, X_dimension) 
            
            list_y_test = []
            for item in y_test:
                list_y_test.append(item.item())
            
            encoded_X_test = encoder(X_test)
            training_generator_sample.append(encoded_X_test)
            target_list = list_y_test

            figure = plt.figure()
            set_classes = set(target_list)
            color_map = plt.cm.rainbow(np.linspace(0, 1, len(set_classes)))
            axis = plt.subplot(111, aspect='equal')
            box = axis.get_position()
            axis.set_position([box.x0, box.y0, box.width * 0.8, box.height])
            handles = [mpatches.Circle((0, 0), label=class_, color=color_map[i]) for i, class_ in enumerate(set_classes)]
            axis.legend(handles=handles, shadow=True, bbox_to_anchor=(1.05, 0.45), fancybox=True, loc='center left')
            kwargs = {'alpha': 0.8, 'c': [color_map[i] for i in target_list]}
            encoded_X_test_cpu = encoded_X_test.cpu()
            plt.scatter(encoded_X_test_cpu[:, 0].detach().numpy(), encoded_X_test_cpu[:, 1].detach().numpy(), s = 2, **kwargs)
            axis.set_xlim([-10, 10])
            axis.set_ylim([-10, 15])

            plt.savefig('latent_space_standard_aae_minimax/epoch_%d.png' % epoch)
            plt.close('all')

            n_digits = 20
            decoded_X_test = decoder(encoder(X_test[:n_digits]))
            decoded_X_test_cpu = decoded_X_test.cpu()
            decoded_X_test_cpu = np.reshape(decoded_X_test_cpu.detach().numpy(), [-1, 28, 28]) * 255
            figure = plt.figure(figsize=(20, 4))

            for i in range (n_digits):
                axis = plt.subplot(2, n_digits, i + 1)
                X_test_cpu = X_test.cpu()
                plt.imshow(X_test_cpu[i].reshape(28, 28).detach().numpy())
                plt.gray()
                axis.get_xaxis().set_visible(False)
                axis.get_yaxis().set_visible(False)
                
                axis = plt.subplot(2, n_digits, i + 1 + n_digits)
                plt.imshow(decoded_X_test_cpu[i])
                plt.gray()
                axis.get_xaxis().set_visible(False)
                axis.get_yaxis().set_visible(False)

            plt.savefig('reconstruction_standard_aae_minimax/epoch_%d.png' % epoch)
            plt.close('all')

            z_sampling = [np.linspace(-3, 3, 10) for i in range (10)]

            n_x, n_y = 10, 10
            plt.subplot()
            grid_spec = gridspec.GridSpec(n_x, n_y, hspace=0.05, wspace=0.05)

            for i, j in enumerate(grid_spec):
                latent_variable = np.concatenate([[z_i[np.random.randint(10)]] for z_i in z_sampling])
                latent_variable = np.reshape(latent_variable, (-1, z_dimension))
                latent_variable = torch.from_numpy(latent_variable).float().cuda(cuda)
                
                reconstructed_x = decoder(latent_variable)
                reconstructed_x_cpu = reconstructed_x.cpu()
                axis = plt.subplot(j)
                image = np.array(reconstructed_x_cpu.detach().numpy().tolist()).reshape(28, 28)
                axis.imshow(image, cmap='gray')
                axis.set_xticks([])
                axis.set_yticks([])
                axis.set_aspect('auto')
            
            plt.savefig('sampling_standard_aae_minimax/epoch_%d.png' % epoch)
            plt.close('all')

            encoder = encoder.train()
            decoder = decoder.train()
            discriminator_gauss = discriminator_gauss.train()
            
    return encoder, decoder

# %%
trained_encoder, trained_decoder = train_model(train_labeled_loader, train_unlabeled_loader, valid_loader)
# Out:
# /usr/local/lib/python3.6/site-packages/torch/tensor.py:362: UserWarning: non-inplace resize is deprecated
#   warnings.warn("non-inplace resize is deprecated")
# /usr/local/lib/python3.6/site-packages/torch/nn/functional.py:1351: UserWarning: nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.
#   warnings.warn("nn.functional.sigmoid is deprecated. Use torch.sigmoid instead.")
# Epoch-0, Time-1.5e+01, Discriminator_loss-1.317, Generator_loss-1.538, reconstruction_loss-0.05382
# Epoch-10, Time-1.5e+01, Discriminator_loss-1.291, Generator_loss-0.8133, reconstruction_loss-0.02976
# Epoch-20, Time-1.5e+01, Discriminator_loss-1.274, Generator_loss-0.7896, reconstruction_loss-0.02672
# Epoch-30, Time-1.5e+01, Discriminator_loss-1.233, Generator_loss-0.8377, reconstruction_loss-0.02728
# Epoch-40, Time-1.6e+01, Discriminator_loss-1.306, Generator_loss-0.7896, reconstruction_loss-0.02806
# Epoch-50, Time-1.5e+01, Discriminator_loss-1.267, Generator_loss-0.802, reconstruction_loss-0.02393
# Epoch-60, Time-1.5e+01, Discriminator_loss-1.253, Generator_loss-0.8189, reconstruction_loss-0.02647
# Epoch-70, Time-1.5e+01, Discriminator_loss-1.18, Generator_loss-0.8044, reconstruction_loss-0.02468
# Epoch-80, Time-1.5e+01, Discriminator_loss-1.16, Generator_loss-0.9481, reconstruction_loss-0.02182
# Epoch-90, Time-1.5e+01, Discriminator_loss-1.087, Generator_loss-0.9747, reconstruction_loss-0.02386
# Epoch-100, Time-1.5e+01, Discriminator_loss-1.138, Generator_loss-0.953, reconstruction_loss-0.02548
# Epoch-110, Time-1.5e+01, Discriminator_loss-1.132, Generator_loss-0.986, reconstruction_loss-0.02435
# Epoch-120, Time-1.5e+01, Discriminator_loss-1.07, Generator_loss-0.89, reconstruction_loss-0.02409
# Epoch-130, Time-1.5e+01, Discriminator_loss-1.009, Generator_loss-0.9402, reconstruction_loss-0.02267
# Epoch-140, Time-1.5e+01, Discriminator_loss-1.081, Generator_loss-1.014, reconstruction_loss-0.02352
# Epoch-150, Time-1.5e+01, Discriminator_loss-1.246, Generator_loss-0.9585, reconstruction_loss-0.02402
# Epoch-160, Time-1.6e+01, Discriminator_loss-1.231, Generator_loss-0.8852, reconstruction_loss-0.02342
# Epoch-170, Time-1.5e+01, Discriminator_loss-1.049, Generator_loss-0.9207, reconstruction_loss-0.02326
# Epoch-180, Time-1.5e+01, Discriminator_loss-1.19, Generator_loss-0.963, reconstruction_loss-0.02193
# Epoch-190, Time-1.5e+01, Discriminator_loss-1.068, Generator_loss-0.8624, reconstruction_loss-0.02403
# Epoch-200, Time-1.5e+01, Discriminator_loss-1.218, Generator_loss-1.048, reconstruction_loss-0.02427
# Epoch-210, Time-1.5e+01, Discriminator_loss-1.237, Generator_loss-1.009, reconstruction_loss-0.02313
# Epoch-220, Time-1.5e+01, Discriminator_loss-1.106, Generator_loss-1.043, reconstruction_loss-0.02083
# Epoch-230, Time-1.5e+01, Discriminator_loss-1.052, Generator_loss-1.069, reconstruction_loss-0.02347
# Epoch-240, Time-1.5e+01, Discriminator_loss-0.9409, Generator_loss-1.144, reconstruction_loss-0.02256
# Epoch-250, Time-1.5e+01, Discriminator_loss-1.012, Generator_loss-1.125, reconstruction_loss-0.02146
# Epoch-260, Time-1.5e+01, Discriminator_loss-1.051, Generator_loss-1.058, reconstruction_loss-0.02307
# Epoch-270, Time-1.5e+01, Discriminator_loss-1.118, Generator_loss-1.077, reconstruction_loss-0.02291
# Epoch-280, Time-1.5e+01, Discriminator_loss-0.9594, Generator_loss-1.103, reconstruction_loss-0.02196
# Epoch-290, Time-1.5e+01, Discriminator_loss-1.058, Generator_loss-1.171, reconstruction_loss-0.0226
# Epoch-300, Time-1.5e+01, Discriminator_loss-1.095, Generator_loss-1.045, reconstruction_loss-0.02365
# Epoch-310, Time-1.5e+01, Discriminator_loss-1.135, Generator_loss-1.213, reconstruction_loss-0.0225
# Epoch-320, Time-1.5e+01, Discriminator_loss-0.9727, Generator_loss-1.089, reconstruction_loss-0.02281
# Epoch-330, Time-1.5e+01, Discriminator_loss-1.164, Generator_loss-1.193, reconstruction_loss-0.02373
# Epoch-340, Time-1.5e+01, Discriminator_loss-1.026, Generator_loss-1.111, reconstruction_loss-0.02248
# Epoch-350, Time-1.5e+01, Discriminator_loss-0.9976, Generator_loss-1.12, reconstruction_loss-0.02239
# Epoch-360, Time-1.5e+01, Discriminator_loss-0.9728, Generator_loss-1.144, reconstruction_loss-0.02275
# Epoch-370, Time-1.5e+01, Discriminator_loss-0.9447, Generator_loss-1.133, reconstruction_loss-0.02055
# Epoch-380, Time-1.5e+01, Discriminator_loss-1.01, Generator_loss-1.126, reconstruction_loss-0.02256
# Epoch-390, Time-1.5e+01, Discriminator_loss-1.064, Generator_loss-0.8746, reconstruction_loss-0.0223
# Epoch-400, Time-1.6e+01, Discriminator_loss-0.984, Generator_loss-1.084, reconstruction_loss-0.02229
# Epoch-410, Time-1.5e+01, Discriminator_loss-1.08, Generator_loss-1.055, reconstruction_loss-0.02205
# Epoch-420, Time-1.5e+01, Discriminator_loss-1.039, Generator_loss-1.143, reconstruction_loss-0.02282
# Epoch-430, Time-1.5e+01, Discriminator_loss-0.9733, Generator_loss-1.025, reconstruction_loss-0.02392
# Epoch-440, Time-1.5e+01, Discriminator_loss-1.029, Generator_loss-1.031, reconstruction_loss-0.02176
# Epoch-450, Time-1.5e+01, Discriminator_loss-1.006, Generator_loss-1.139, reconstruction_loss-0.02463
# Epoch-460, Time-1.5e+01, Discriminator_loss-1.078, Generator_loss-1.12, reconstruction_loss-0.02384
# Epoch-470, Time-1.5e+01, Discriminator_loss-1.055, Generator_loss-1.07, reconstruction_loss-0.02304
# Epoch-480, Time-1.5e+01, Discriminator_loss-1.074, Generator_loss-1.08, reconstruction_loss-0.02254
# Epoch-490, Time-1.6e+01, Discriminator_loss-0.9253, Generator_loss-1.114, reconstruction_loss-0.02139
# Epoch-500, Time-1.6e+01, Discriminator_loss-0.9833, Generator_loss-1.208, reconstruction_loss-0.02276
# Epoch-510, Time-1.5e+01, Discriminator_loss-1.018, Generator_loss-1.098, reconstruction_loss-0.02192
# Epoch-520, Time-1.5e+01, Discriminator_loss-0.9817, Generator_loss-1.119, reconstruction_loss-0.02275
# Epoch-530, Time-1.5e+01, Discriminator_loss-1.222, Generator_loss-1.116, reconstruction_loss-0.02187
# Epoch-540, Time-1.5e+01, Discriminator_loss-1.199, Generator_loss-0.9932, reconstruction_loss-0.02209
# Epoch-550, Time-1.5e+01, Discriminator_loss-1.042, Generator_loss-1.092, reconstruction_loss-0.02172
# Epoch-560, Time-1.5e+01, Discriminator_loss-0.9874, Generator_loss-1.084, reconstruction_loss-0.02321
# Epoch-570, Time-1.5e+01, Discriminator_loss-1.079, Generator_loss-1.045, reconstruction_loss-0.02209
# Epoch-580, Time-1.5e+01, Discriminator_loss-1.021, Generator_loss-1.142, reconstruction_loss-0.02241
# Epoch-590, Time-1.5e+01, Discriminator_loss-1.062, Generator_loss-1.099, reconstruction_loss-0.02145
# Epoch-600, Time-1.5e+01, Discriminator_loss-1.07, Generator_loss-1.101, reconstruction_loss-0.02038
# Epoch-610, Time-1.5e+01, Discriminator_loss-1.021, Generator_loss-1.178, reconstruction_loss-0.02402
# Epoch-620, Time-1.5e+01, Discriminator_loss-1.027, Generator_loss-1.075, reconstruction_loss-0.02087
# Epoch-630, Time-1.5e+01, Discriminator_loss-0.9535, Generator_loss-1.192, reconstruction_loss-0.02167
# Epoch-640, Time-1.5e+01, Discriminator_loss-1.027, Generator_loss-1.263, reconstruction_loss-0.02347
# Epoch-650, Time-1.5e+01, Discriminator_loss-1.019, Generator_loss-1.122, reconstruction_loss-0.02092
# Epoch-660, Time-1.5e+01, Discriminator_loss-1.023, Generator_loss-1.151, reconstruction_loss-0.02268
# Epoch-670, Time-1.6e+01, Discriminator_loss-1.056, Generator_loss-1.078, reconstruction_loss-0.02278
# Epoch-680, Time-1.5e+01, Discriminator_loss-0.9666, Generator_loss-1.067, reconstruction_loss-0.02333
# Epoch-690, Time-1.5e+01, Discriminator_loss-0.9975, Generator_loss-1.233, reconstruction_loss-0.02068
# Epoch-700, Time-1.5e+01, Discriminator_loss-0.9979, Generator_loss-1.32, reconstruction_loss-0.0232
# Epoch-710, Time-1.5e+01, Discriminator_loss-1.038, Generator_loss-1.328, reconstruction_loss-0.02129
# Epoch-720, Time-1.5e+01, Discriminator_loss-0.9895, Generator_loss-1.096, reconstruction_loss-0.02192
# Epoch-730, Time-1.5e+01, Discriminator_loss-0.912, Generator_loss-1.116, reconstruction_loss-0.02196
# Epoch-740, Time-1.5e+01, Discriminator_loss-1.081, Generator_loss-1.156, reconstruction_loss-0.02134
# Epoch-750, Time-1.5e+01, Discriminator_loss-1.018, Generator_loss-1.095, reconstruction_loss-0.0221
# Epoch-760, Time-1.5e+01, Discriminator_loss-0.9743, Generator_loss-1.075, reconstruction_loss-0.02373
# Epoch-770, Time-1.5e+01, Discriminator_loss-0.9602, Generator_loss-1.138, reconstruction_loss-0.02397
# Epoch-780, Time-1.5e+01, Discriminator_loss-1.004, Generator_loss-1.093, reconstruction_loss-0.02192
# Epoch-790, Time-1.5e+01, Discriminator_loss-1.01, Generator_loss-1.154, reconstruction_loss-0.02319
# Epoch-800, Time-1.5e+01, Discriminator_loss-1.096, Generator_loss-1.043, reconstruction_loss-0.02369
# Epoch-810, Time-1.6e+01, Discriminator_loss-1.105, Generator_loss-1.063, reconstruction_loss-0.02275
# Epoch-820, Time-1.5e+01, Discriminator_loss-1.051, Generator_loss-1.189, reconstruction_loss-0.0233
# Epoch-830, Time-1.5e+01, Discriminator_loss-1.184, Generator_loss-1.11, reconstruction_loss-0.02243
# Epoch-840, Time-1.8e+01, Discriminator_loss-1.049, Generator_loss-1.276, reconstruction_loss-0.02139
# Epoch-850, Time-1.5e+01, Discriminator_loss-1.073, Generator_loss-1.254, reconstruction_loss-0.02293
# Epoch-860, Time-1.5e+01, Discriminator_loss-0.9371, Generator_loss-1.188, reconstruction_loss-0.02184
# Epoch-870, Time-1.6e+01, Discriminator_loss-0.8779, Generator_loss-1.265, reconstruction_loss-0.02009
# Epoch-880, Time-1.6e+01, Discriminator_loss-1.106, Generator_loss-1.016, reconstruction_loss-0.02163
# Epoch-890, Time-1.5e+01, Discriminator_loss-0.9884, Generator_loss-1.094, reconstruction_loss-0.02187
# Epoch-900, Time-1.5e+01, Discriminator_loss-0.9779, Generator_loss-1.259, reconstruction_loss-0.02343
# Epoch-910, Time-1.5e+01, Discriminator_loss-1.035, Generator_loss-1.188, reconstruction_loss-0.02193
# Epoch-920, Time-1.5e+01, Discriminator_loss-1.089, Generator_loss-1.087, reconstruction_loss-0.02291
# Epoch-930, Time-1.5e+01, Discriminator_loss-0.9995, Generator_loss-1.027, reconstruction_loss-0.02184
# Epoch-940, Time-1.5e+01, Discriminator_loss-0.963, Generator_loss-1.252, reconstruction_loss-0.02212
# Epoch-950, Time-1.5e+01, Discriminator_loss-0.9229, Generator_loss-1.187, reconstruction_loss-0.02149
# Epoch-960, Time-1.5e+01, Discriminator_loss-1.103, Generator_loss-1.008, reconstruction_loss-0.0234
# Epoch-970, Time-1.5e+01, Discriminator_loss-1.067, Generator_loss-1.051, reconstruction_loss-0.02276
# Epoch-980, Time-1.6e+01, Discriminator_loss-0.9505, Generator_loss-1.024, reconstruction_loss-0.02416
# Epoch-990, Time-1.5e+01, Discriminator_loss-0.9658, Generator_loss-1.027, reconstruction_loss-0.02279

# %%
file_location_encoder = "minimax-standard-encoder.pt"
file_location_decoder = "minimax-standard-decoder.pt"
torch.save(trained_encoder.state_dict(), file_location_encoder)
torch.save(trained_decoder.state_dict(), file_location_decoder)
